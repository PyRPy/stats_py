# %%
# Chapter 4 Algebra and symbolic math with sympy - 2

# %%
## solving a system of linear equations

# %%
from sympy import Symbol, solve, pprint

# %%
x = Symbol('x')
y = Symbol('y')
expr1 = 2*x + 3*y - 6
expr2 = 3*x + 2*y - 12

solve((expr1, expr2), dict=True)
# Out:
# [{x: 24/5, y: -6/5}]

# %%
soln = solve((expr1, expr2), dict=True)
soln = soln[0]

# %%
expr1.subs({x:soln[x], y:soln[y]})
# Out:
# 0

# %%
expr2.subs({x:soln[x], y:soln[y]})
# Out:
# 0

# %%
## plotting using sympy

# %%
from sympy.plotting import plot
from sympy import Symbol
x = Symbol('x')
plot(2*x + 3)

# %%
plot((2*x + 3), (x, -5, 5))

# %%
p = plot(2*x + 3, (x, -5, 5), title='a line', xlabel='x', ylabel='2x+3', show=False)

# %%
p.save('line.png')

# %%
## plotting expression input by the user

# %%
"""
plot the graph of an input expression
"""

# %%
from sympy import Symbol, sympify, solve
from sympy.plotting import plot
from sympy.core.sympify import SympifyError

# %%
def plot_expression(expr):
    y = Symbol('y')
    solutions = solve(expr, y)
    expr_y = solutions[0]
    plot(expr_y)

# %%
expr = input('enter your expression in terms of x and y: ')
# Out:
# enter your expression in terms of x and y: 2*x - 1

# %%
try:
    expr = sympify(expr)
except SympifyError:
    print('invalide input')
else:
    plot_expression(expr)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-c1f1695981e6> in <module>()
#       4     print('invalide input')
#       5 else:
# ----> 6     plot_expression(expr)
#
# <ipython-input-30-43b10692859d> in plot_expression(expr)
#       2     y = Symbol('y')
#       3     solutions = solve(expr, y)
# ----> 4     expr_y = solutions[0]
#       5     plot(expr_y)
#
# IndexError: list index out of range

# %%
plot(2*x - 1)

# %%
from sympy.plotting import plot
from sympy import Symbol
x = Symbol('x')
p = plot(2*x + 3, 3*x + 1, legend=True, show=False)
p[0].line_color = 'b'
p[1].line_color = 'r'
p.show()
