# %%
# how does the exponential distribution look like ?

# %%
# required libraries
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# produce random numbers with expoential distribution
x = random.exponential(size = 10000)

# %%
# plot histogram in seaborn
sns.histplot(x)
plt.show()
